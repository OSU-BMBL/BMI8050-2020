# %%
import numpy as np
import pandas as pd
from keras.layers import Dense
from keras.layers import Dropout
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from keras.optimizers import Adam,SGD
from sklearn.decomposition import PCA
from keras.models import Sequential, Model
from sklearn.cluster import KMeans
import sklearn.metrics as metrics
from sklearn.preprocessing import MinMaxScaler

# %%
counts = pd.read_csv('counts_K8_N1200.csv')
z = pd.read_csv('z_K8_N1200.csv')

# %%
z = z.to_numpy()

# %%
X = counts
n_input_1 = 50
x_train_1 = PCA(n_components = n_input_1).fit_transform(X)
x_train_1 = MinMaxScaler().fit_transform(x_train_1)
X = x_train_1

# %%
# 5 LAYER
n_input = X.shape[1]
x_train = X
# Autoencoder
model = Sequential()

# Encoder
model.add(Dense(10,       activation='elu', input_shape=(n_input,)))
#model.add(Dense(8,       activation='elu'))
model.add(Dense(6,       activation='elu'))
#model.add(Dense(4,       activation='elu'))

# Bottleneck
model.add(Dense(2,        activation='linear', name="bottleneck"))

# Decoder
#model.add(Dense(4,       activation='elu'))
model.add(Dense(6,       activation='elu'))
#model.add(Dense(8,       activation='elu'))
model.add(Dense(10,       activation='elu'))

# Output layer
model.add(Dense(n_input,  activation='sigmoid'))

# Compile
model.compile(loss = 'mean_squared_error', optimizer = Adam())
model.summary()
history_1 = model.fit(x_train, x_train, epochs=1000, batch_size=128, shuffle=True,validation_split=0.5, verbose = 1)

#plot our loss 
plt.plot(history_1.history['loss'])
plt.plot(history_1.history['val_loss'])
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# Obtain bottleneck
encoder = Model(model.input, model.get_layer('bottleneck').output)
bottleneck_representation = encoder.predict(x_train)
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 10)                510
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 66
# _________________________________________________________________
# bottleneck (Dense)           (None, 2)                 14
# _________________________________________________________________
# dense_2 (Dense)              (None, 6)                 18
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                70
# _________________________________________________________________
# dense_4 (Dense)              (None, 50)                550
# ...
# Total params: 1,228
# Trainable params: 1,228
# Non-trainable params: 0
# _________________________________________________________________
# ...

# %%
# Plot results
plt.scatter(bottleneck_representation[:,0], bottleneck_representation[:,1], c = z, s = 10, cmap = 'tab20')
plt.title('Autoencoder: 5 Layers')
plt.xlabel("Dimension 1")
plt.ylabel("Dimension 2")
# Out:
# Text(0, 0.5, 'Dimension 2')

# %%
# 7- LAYER
# Autoencoder
model = Sequential()

# Encoder
model.add(Dense(10,       activation='elu', input_shape=(n_input,)))
model.add(Dense(8,       activation='elu'))
model.add(Dense(6,       activation='elu'))
#model.add(Dense(4,       activation='elu'))

# Bottleneck
model.add(Dense(2,        activation='linear', name="bottleneck"))

# Decoder
#model.add(Dense(4,       activation='elu'))
model.add(Dense(6,       activation='elu'))
model.add(Dense(8,       activation='elu'))
model.add(Dense(10,       activation='elu'))

# Output layer
model.add(Dense(n_input,  activation='sigmoid'))

# Compile
model.compile(loss = 'mean_squared_error', optimizer = Adam())
model.summary()
history_1 = model.fit(x_train, x_train, epochs=1000, batch_size=128, shuffle=True,validation_split=0.5, verbose = 1)

#plot our loss 
plt.plot(history_1.history['loss'])
plt.plot(history_1.history['val_loss'])
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# Obtain bottleneck
encoder = Model(model.input, model.get_layer('bottleneck').output)
bottleneck_representation = encoder.predict(x_train)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_48 (Dense)             (None, 10)                510
# _________________________________________________________________
# dense_49 (Dense)             (None, 8)                 88
# _________________________________________________________________
# dense_50 (Dense)             (None, 6)                 54
# _________________________________________________________________
# bottleneck (Dense)           (None, 2)                 14
# _________________________________________________________________
# dense_51 (Dense)             (None, 6)                 18
# _________________________________________________________________
# dense_52 (Dense)             (None, 8)                 56
# _________________________________________________________________
# dense_53 (Dense)             (None, 10)                90
# ...

# %%
# 3 LAYER
# Autoencoder
model = Sequential()

# Encoder
model.add(Dense(10,       activation='elu', input_shape=(n_input,)))
#model.add(Dense(8,       activation='elu'))
#model.add(Dense(6,       activation='elu'))
#model.add(Dense(4,       activation='elu'))

# Bottleneck
model.add(Dense(2,        activation='linear', name="bottleneck"))

# Decoder
#model.add(Dense(4,       activation='elu'))
#model.add(Dense(6,       activation='elu'))
#model.add(Dense(8,       activation='elu'))
model.add(Dense(10,       activation='elu'))

# Output layer
model.add(Dense(n_input,  activation='sigmoid'))

# Compile
model.compile(loss = 'mean_squared_error', optimizer = Adam())
model.summary()
history_1 = model.fit(x_train, x_train, epochs=1000, batch_size=128, shuffle=True,validation_split=0.5, verbose = 1)

#plot our loss 
plt.plot(history_1.history['loss'])
plt.plot(history_1.history['val_loss'])
plt.title('model train vs validation loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# Obtain bottleneck
encoder = Model(model.input, model.get_layer('bottleneck').output)
bottleneck_representation = encoder.predict(x_train)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_55 (Dense)             (None, 10)                510
# _________________________________________________________________
# bottleneck (Dense)           (None, 2)                 22
# _________________________________________________________________
# dense_56 (Dense)             (None, 10)                30
# _________________________________________________________________
# dense_57 (Dense)             (None, 50)                550
# ...
# Total params: 1,112
# Trainable params: 1,112
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0210 - val_loss: 0.0210
# Epoch 2/1000
# 5/5 [==============================] - 0s 8ms/step - loss: 0.0203 - val_loss: 0.0207
# Epoch 3/1000
# ...
